# %%
# from functools import partial
from pathlib import Path
# from typing import Optional, Tuple
# import cv2
# import fire
import numpy as np
import torch
import torch.nn.functional as F
from accelerate import Accelerator
from PIL import Image
from scipy.sparse.linalg import eigsh
# from sklearn.cluster import KMeans, MiniBatchKMeans
# from sklearn.decomposition import PCA
# from torchvision.utils import draw_bounding_boxes
from tqdm import tqdm
import extract_utils as utils
from torch.utils.data import Dataset, DataLoader
from lightly.loss import NegativeCosineSimilarity
from lightly.models.modules import SimSiamPredictionHead, SimSiamProjectionHead
from torch import nn
import torchvision

# %% [markdown]
# ## Extract Eigen Vectors

# %%
images_root="/home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/images"
features_dir="/home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16"
output_dir="//home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/eigs_dot1projpredconv1Dsimsiam_ds_10_jn"
which_matrix= 'laplacian'
which_color_matrix= 'knn'
which_features= 'k'
normalize=True
threshold_at_zero=True
lapnorm= True
K= 5
image_downsample_factor = None
image_color_lambda = 0.0
multiprocessing = 0
batch_size=2
epochs=10

# %% [markdown]
# ## ResNet Residual Block

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channels=1, out_channels=1, stride=1, downsample=None):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=in_channels, out_channels=128, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm1d(128)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv1d(128, out_channels * self.expansion, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm1d(out_channels * self.expansion)
        self.downsample = downsample

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.downsample is not None:
            identity = self.downsample(x)

        out += identity
        out = self.relu(out)
        # print("Before squeezing, out shape=", out.shape)
        out =  out.squeeze().to('cuda')
        # print("After squeezing, out shape=", out.shape)

        return out

# %%
# class ResidualBlock(nn.Module):
#     def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False):
#         super(ResidualBlock, self).__init__()
#         self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
#         self.bn1 = nn.BatchNorm1d(out_channels)
#         self.relu = nn.ReLU(inplace=True)
#         self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding, bias=bias)
#         self.bn2 = nn.BatchNorm1d(out_channels)
#         # shortcut connection
#         self.shortcut = nn.Sequential()
#         if stride != 1 or in_channels != out_channels:
#             self.shortcut = nn.Sequential(
#                 nn.Conv1d(in_channels, out_channels, kernel_size=1, stride=stride, bias=bias),
#                 nn.BatchNorm1d(out_channels)
#             )
#
#     def forward(self, x):
#         residual = x
#
#         out = self.conv1(x)
#         out = self.bn1(out)
#         out = self.relu(out)
#
#         out = self.conv2(out)
#         out = self.bn2(out)
#
#         out += self.shortcut(residual)
#         out = self.relu(out)
#
#         return out
# class ResNetBlock(nn.Module):
#     def __init__(self, in_channels, out_channels, stride=1, downsample=None):
#         super(ResNetBlock, self).__init__()
#         self.conv1 = nn.Conv1d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
#         self.bn1 = nn.BatchNorm1d(out_channels)
#         self.relu = nn.ReLU(inplace=True)
#         self.conv2 = nn.Conv1d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
#         self.bn2 = nn.BatchNorm1d(out_channels)
#         self.downsample = downsample
#
#     def forward(self, x):
#         identity = x
#
#         out = self.conv1(x)
#         out = self.bn1(out)
#         out = self.relu(out)
#
#         out = self.conv2(out)
#         out = self.bn2(out)
#
#         if self.downsample is not None:
#             identity = self.downsample(x)
#
#         out += identity
#         out = self.relu(out)
#
#         return out

# %% [markdown]
# ## Incorporating SimSiam

# %%
# Define a custom dataset class
class Feature_Dataset(Dataset):
    def __init__(self, features):
        self.features = features

    def __getitem__(self, index):
        return self.features[index]

    def __len__(self):
        return len(self.features)

# %%
# print(feats.shape)

# %%
class SimSiam(nn.Module):
    def __init__(self, train=True):
        super().__init__()
        # self.projection_head = SimSiamProjectionHead(feats.shape[1], 128,feats.shape[1])
        self.train=train
        self.projection_head = BasicBlock()
        # self.projection_head = ResidualBlock(feats.shape[1], feats.shape[1])
        # self.prediction_head = SimSiamPredictionHead(feats.shape[1], 128, feats.shape[1])
        self.prediction_head = BasicBlock()

    def forward(self, x,train=True):
        z = self.projection_head(x)
        # print("z.shape", z.shape)
        if train:
            z_new = z.view(2, 1, 384)
        else:
            z_new=z.view(feats.shape[0],1 , 384)
            # print(z_new.shape)
        p = self.prediction_head(z_new)
        z_new.detach()
        # if train:
        #     z_new = z.view(2, 1, 384)
        #     # print(z_new.shape)
        #     p = self.prediction_head(z_new)
        #     z_new.detach()
        # else:
        #     p = self.prediction_head(z)
        # z = z.detach()
        return z_new, p

# %%
# utils.make_output_dir(output_dir)
# feat_list=[]
# inputs = list(enumerate(sorted(Path(features_dir).iterdir())))
# batch_size=2
# token_feature_size=384
# for inp in tqdm(inputs[:2]):
#     index, features_file = inp
#     print(index, features_file)
#      # Load
#     data_dict = torch.load(features_file, map_location='cpu')
#     # Load affinity matrix
#     # feats_unsqueeze=data_dict[which_features].cuda()
#     feats = data_dict[which_features].squeeze().cuda()
#     print(feats.shape)
#     # print(feats_unsqueeze.shape)
#     feat_dataset = Feature_Dataset(feats)
#     features_dataloader = DataLoader(feat_dataset, batch_size=2, shuffle=True)
#     i=0
#     for x0 in features_dataloader:
#         if i==0:
#         # for (x0), _, _ in features_dataloader:
#             print("before unsqueezing x0.shape=", x0.shape)
#             x0 = x0.unsqueeze(0).to(device)
#             x1=torchvision.transforms.RandomAffine(0)(x0)
#             x0 = x0.squeeze(0).to(device)
#             x0 = torch.tensor(x0).view(batch_size, 1, 1, token_feature_size)
#             print("After squeezing and viewing x0 shape=", x0.shape)
#             # print("x0.shape=", x0.shape)
#             x1 = x1.squeeze(0).to(device)
#             x1 = torch.tensor(x1).view(batch_size, 1, 1,token_feature_size)
#             print("After squeezing and viewing x0 shape=", x1.shape)
#             print("x1 shape=", x1.shape)
#         else:
#             break
#         i+=1

# %%
utils.make_output_dir(output_dir)
feat_list=[]
inputs = list(enumerate(sorted(Path(features_dir).iterdir())))
for inp in tqdm(inputs[123:124]):
    index, features_file = inp
    print(index, features_file)
     # Load
    data_dict = torch.load(features_file, map_location='cpu')
    # print(data_dict.keys())   #['k', 'indices', 'file', 'id', 'model_name', 'patch_size', 'shape']
    # print("shape=", data_dict['shape'], "k shape", data_dict['k'].shape, "patch_size=", data_dict['patch_size'])
    image_id = data_dict['file'][:-4]
    print(image_id)
    # Load
    output_file = str(Path(output_dir) / f'{image_id}.pth')
    if Path(output_file).is_file():
        print(f'Skipping existing file {str(output_file)}')
        # break
        # return  # skip because already generated

    # Load affinity matrix
    feats = data_dict[which_features].squeeze().cuda()
    # print("Without normalizing, Features Shape is",feats.shape)
    if normalize:
        feats = F.normalize(feats, p=2, dim=-1)
    # print("After normalization, Features Shape",feats.shape)
    # print("which_matrix=", which_matrix)
    # Eigenvectors of affinity matrix
    if which_matrix == 'affinity_torch':
        W = feats @ feats.T
        # W_feat=contrastive_affinity(feats, feats.T)
        # print("W shape=", W.shape)
        if threshold_at_zero:
            W = (W * (W > 0))
            # print("W shape=", W.shape)
        eigenvalues, eigenvectors = torch.eig(W, eigenvectors=True)
        eigenvalues = eigenvalues.cpu()
        eigenvectors = eigenvectors.cpu()
        print("which matrix=",which_matrix, "eigenvalues shape", eigenvalues.shape, "eigenvectors shape", eigenvectors.shape)


    # Eigenvectors of affinity matrix with scipy
    elif which_matrix == 'affinity_svd':
        USV = torch.linalg.svd(feats, full_matrices=False)
        eigenvectors = USV[0][:, :K].T.to('cpu', non_blocking=True)
        eigenvalues = USV[1][:K].to('cpu', non_blocking=True)
        print("which matrix=",which_matrix,"eigenvalues shape", eigenvalues.shape, "eigenvectors shape", eigenvectors.shape)

    # Eigenvectors of affinity matrix with scipy
    elif which_matrix == 'affinity':
        # print("Without normalizing, Features Shape is",feats.shape)
        W = (feats @ feats.T)
        # W_feat=contrastive_affinity(feats, feats.T)
        # print("W shape=", W.shape)
        if threshold_at_zero:
            W = (W * (W > 0))
        W = W.cpu().numpy()
        # print("W shape=", W.shape)
        eigenvalues, eigenvectors = eigsh(W, which='LM', k=K)
        eigenvectors = torch.flip(torch.from_numpy(eigenvectors), dims=(-1,)).T
        print("which matrix=",which_matrix, "eigenvalues shape", eigenvalues.shape, "eigenvectors shape", eigenvectors.shape)

    # Eigenvectors of matting laplacian matrix
    elif which_matrix in ['matting_laplacian', 'laplacian']:

        # Get sizes
        B, C, H, W, P, H_patch, W_patch, H_pad, W_pad = utils.get_image_sizes(data_dict)
        if image_downsample_factor is None:
            image_downsample_factor = P
        H_pad_lr, W_pad_lr = H_pad // image_downsample_factor, W_pad // image_downsample_factor

        # Upscale features to match the resolution
        if (H_patch, W_patch) != (H_pad_lr, W_pad_lr):
            feats = F.interpolate(
                feats.T.reshape(1, -1, H_patch, W_patch),
                size=(H_pad_lr, W_pad_lr), mode='bilinear', align_corners=False
            ).reshape(-1, H_pad_lr * W_pad_lr).T

        ### Feature affinities
        # print("Without normalizing, Features Shape is",feats.shape)

        W_feat_ds = (feats @ feats.T)
        # feat_list.append(feats)
        feat_dataset = Feature_Dataset(feats)
        if feats.shape[0]%2==0:
            features_dataloader = DataLoader(feat_dataset, batch_size=batch_size, shuffle=True)
        else:
            features_dataloader = DataLoader(feat_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
        model_simsiam = SimSiam()
        device = "cuda" if torch.cuda.is_available() else "cpu"
        model_simsiam.to(device)
        criterion = NegativeCosineSimilarity()
        optimizer = torch.optim.SGD(model_simsiam.parameters(), lr=0.06)
        print("Starting Training")
        for epoch in range(epochs):
            total_loss = 0
            for x0 in features_dataloader:
            # for (x0), _, _ in features_dataloader:
                print("Before Unsqueezing, x0 shape=", x0.shape)
                x0 = x0.unsqueeze(0).to(device)
                # x0 = x0.unsqueeze(1).to(device)
                print("After Unsqueezing x0 shape=", x0.shape)
                x1=torchvision.transforms.RandomAffine(0)(x0)
                # print("After Unsqueezing x1 shape=", x1.shape)
                # x0 = x0.squeeze(0).to(device)
                # print("batch_size=",batch_size)
                # x0_new = torch.tensor(x0).view(batch_size, 1, 1, 384)
                # x0_new = torch.tensor(x0).view(batch_size, 1, 384)
                x0_new = x0.view(batch_size, 1, 384)
                # print("After viewing x0 shape=", x0_new.shape)
                # print("x0.shape=", x0.shape)
                # x1 = x1.squeeze(0).to(device)
                # x1 = torch.tensor(x1).view(batch_size, 1, 1,384)
                x1_new = x1.view(batch_size, 1, 384)
                # print("After viewing x1 shape=", x1_new.shape)
                z0, p0 = model_simsiam(x0_new, True)
                # print("zo.shape", z0.shape)
                # print("p0.shape", p0.shape)
                z1, p1 = model_simsiam(x1_new, True)
                loss = 0.5 * (criterion(z0, p1) + criterion(z1, p0))
                total_loss += loss.detach()
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
            avg_loss = total_loss / len(features_dataloader)
            print(f"epoch: {epoch:>02}, loss: {avg_loss:.5f}")
        feats=feats.unsqueeze(1).to(device)
        # feats=feats.unsqueeze(2).to(device)
        print("After Unsqueezing, feature size=", feats.shape)
        proj_pred_feature=model_simsiam(feats, False)
        projected_feature=proj_pred_feature[0]
        projected_feature = projected_feature.squeeze().to(device)
        print("type(projected_feature)", type(projected_feature))
        print("projected feature shape=", projected_feature.shape)
        W_feat_siam=torch.matmul(projected_feature, projected_feature.t())
        W_feat=W_feat_ds + 0.1*W_feat_siam
        # print("W_feat.shape=", W_feat.shape)
        # print("W_feat.shape=", W_feat.shape)
        # W_feat=contrastive_affinity(feats, feats.T)
        if threshold_at_zero:
            W_feat = (W_feat * (W_feat > 0))
        W_feat = W_feat / W_feat.max()  # NOTE: If features are normalized, this naturally does nothing
        # W_feat = W_feat.cpu().numpy()
        W_feat = W_feat.detach().cpu().numpy()
        # print("W_feat shape=",W_feat.shape)

        ### Color affinities
        # If we are fusing with color affinites, then load the image and compute
        if image_color_lambda > 0:

            # Load image
            image_file = str(Path(images_root) / f'{image_id}.jpg')
            image_lr = Image.open(image_file).resize((W_pad_lr, H_pad_lr), Image.BILINEAR)
            image_lr = np.array(image_lr) / 255.

            # Color affinities (of type scipy.sparse.csr_matrix)
            if which_color_matrix == 'knn':
                W_lr = utils.knn_affinity(image_lr / 255)
            elif which_color_matrix == 'rw':
                W_lr = utils.rw_affinity(image_lr / 255)

            # Convert to dense numpy array
            W_color = np.array(W_lr.todense().astype(np.float32))
            # print("W_color shape", W_color.shape)

        else:

            # No color affinity
            W_color = 0

        # Combine
        W_comb = W_feat + W_color * image_color_lambda  # combination
        D_comb = np.array(utils.get_diagonal(W_comb).todense())  # is dense or sparse faster? not sure, should check
        # print("W_comb shape= ", W_comb.shape, "D_comb shape",  D_comb.shape)
        if lapnorm:
            try:
                eigenvalues, eigenvectors = eigsh(D_comb - W_comb, k=K, sigma=0, which='LM', M=D_comb)
            except:
                eigenvalues, eigenvectors = eigsh(D_comb - W_comb, k=K, which='SM', M=D_comb)
        else:
            try:
                eigenvalues, eigenvectors = eigsh(D_comb - W_comb, k=K, sigma=0, which='LM')
            except:
                eigenvalues, eigenvectors = eigsh(D_comb - W_comb, k=K, which='SM')
        eigenvalues, eigenvectors = torch.from_numpy(eigenvalues), torch.from_numpy(eigenvectors.T).float()
    print("eigenvalues shape", eigenvalues.shape, "eigenvectors shape", eigenvectors.shape)
    # Sign ambiguity
    for k in range(eigenvectors.shape[0]):
        if 0.5 < torch.mean((eigenvectors[k] > 0).float()).item() < 1.0:  # reverse segment
            eigenvectors[k] = 0 - eigenvectors[k]

    # Save dict
    output_dict = {'eigenvalues': eigenvalues, 'eigenvectors': eigenvectors}
    torch.save(output_dict, output_file)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# 0 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0001.pth
# 0001
# Starting Training
# epoch: 00, loss: -0.43771
# epoch: 01, loss: -0.42916
# epoch: 02, loss: -0.43295
# epoch: 03, loss: -0.43521
# epoch: 04, loss: -0.43588
# epoch: 05, loss: -0.43666
# epoch: 06, loss: -0.43801
# epoch: 07, loss: -0.43900
# epoch: 08, loss: -0.43944
# epoch: 09, loss: -0.43939
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   0%|          | 1/1000 [00:22<6:20:35, 22.86s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 1 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0002.pth
# 0002
# Starting Training
# epoch: 00, loss: -0.37975
# epoch: 01, loss: -0.38518
# epoch: 02, loss: -0.38581
# epoch: 03, loss: -0.38632
# epoch: 04, loss: -0.38766
# epoch: 05, loss: -0.38737
# epoch: 06, loss: -0.38688
# epoch: 07, loss: -0.38743
# epoch: 08, loss: -0.38719
# epoch: 09, loss: -0.38696
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   0%|          | 2/1000 [00:42<5:44:28, 20.71s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 2 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0003.pth
# 0003
# Starting Training
# epoch: 00, loss: -0.36473
# epoch: 01, loss: -0.37693
# epoch: 02, loss: -0.38749
# epoch: 03, loss: -0.39616
# epoch: 04, loss: -0.40294
# epoch: 05, loss: -0.41044
# epoch: 06, loss: -0.41563
# epoch: 07, loss: -0.41982
# epoch: 08, loss: -0.42169
# epoch: 09, loss: -0.42348
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   0%|          | 3/1000 [01:01<5:31:47, 19.97s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 3 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0004.pth
# 0004
# Starting Training
# epoch: 00, loss: -0.38699
# epoch: 01, loss: -0.39220
# epoch: 02, loss: -0.39603
# epoch: 03, loss: -0.39764
# epoch: 04, loss: -0.40136
# epoch: 05, loss: -0.40312
# epoch: 06, loss: -0.40408
# epoch: 07, loss: -0.40467
# epoch: 08, loss: -0.40577
#   0%|          | 4/1000 [01:19<5:21:01, 19.34s/it]
# epoch: 09, loss: -0.40667
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 4 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0005.pth
# 0005
# Starting Training
# epoch: 00, loss: -0.38266
# epoch: 01, loss: -0.37814
# epoch: 02, loss: -0.37441
# epoch: 03, loss: -0.37381
# epoch: 04, loss: -0.37378
# epoch: 05, loss: -0.37505
# epoch: 06, loss: -0.37694
# epoch: 07, loss: -0.37805
# epoch: 08, loss: -0.37925
#   0%|          | 5/1000 [01:37<5:12:01, 18.82s/it]
# epoch: 09, loss: -0.38134
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 5 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0006.pth
# 0006
# Starting Training
# epoch: 00, loss: -0.59637
# epoch: 01, loss: -0.63007
# epoch: 02, loss: -0.63165
# epoch: 03, loss: -0.63241
# epoch: 04, loss: -0.63305
# epoch: 05, loss: -0.63408
# epoch: 06, loss: -0.63448
# epoch: 07, loss: -0.63498
# epoch: 08, loss: -0.63548
#   1%|          | 6/1000 [01:55<5:07:45, 18.58s/it]
# epoch: 09, loss: -0.63605
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 6 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0007.pth
# 0007
# Starting Training
# epoch: 00, loss: -0.35701
# epoch: 01, loss: -0.35943
# epoch: 02, loss: -0.36075
# epoch: 03, loss: -0.36230
# epoch: 04, loss: -0.36365
# epoch: 05, loss: -0.36428
# epoch: 06, loss: -0.36461
# epoch: 07, loss: -0.36513
# epoch: 08, loss: -0.36609
#   1%|          | 7/1000 [02:12<5:00:19, 18.15s/it]
# epoch: 09, loss: -0.36545
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 7 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0008.pth
# 0008
# Starting Training
# epoch: 00, loss: -0.34844
# epoch: 01, loss: -0.35199
# epoch: 02, loss: -0.35637
# epoch: 03, loss: -0.36303
# epoch: 04, loss: -0.36647
# epoch: 05, loss: -0.36949
# epoch: 06, loss: -0.37339
# epoch: 07, loss: -0.37555
# epoch: 08, loss: -0.37787
# epoch: 09, loss: -0.37847
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   1%|          | 8/1000 [02:31<5:00:58, 18.20s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 8 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0009.pth
# 0009
# Starting Training
# epoch: 00, loss: -0.41514
# epoch: 01, loss: -0.43232
# epoch: 02, loss: -0.43399
# epoch: 03, loss: -0.43711
# epoch: 04, loss: -0.43963
# epoch: 05, loss: -0.44308
# epoch: 06, loss: -0.44492
# epoch: 07, loss: -0.44785
# epoch: 08, loss: -0.45003
# epoch: 09, loss: -0.45226
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   1%|          | 9/1000 [02:49<5:00:01, 18.17s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 9 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0010.pth
# 0010
# Starting Training
# epoch: 00, loss: -0.39163
# epoch: 01, loss: -0.40187
# epoch: 02, loss: -0.40576
# epoch: 03, loss: -0.40742
# epoch: 04, loss: -0.40862
# epoch: 05, loss: -0.41076
# epoch: 06, loss: -0.41108
# epoch: 07, loss: -0.41229
# epoch: 08, loss: -0.41305
#   1%|          | 10/1000 [03:09<5:10:12, 18.80s/it]
# epoch: 09, loss: -0.41617
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 10 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0011.pth
# 0011
# Starting Training
# epoch: 00, loss: -0.41398
# epoch: 01, loss: -0.43198
# epoch: 02, loss: -0.43014
# epoch: 03, loss: -0.43019
# epoch: 04, loss: -0.43036
# epoch: 05, loss: -0.43054
# epoch: 06, loss: -0.43124
# epoch: 07, loss: -0.43213
# epoch: 08, loss: -0.43274
#   1%|          | 11/1000 [03:26<5:02:23, 18.35s/it]
# epoch: 09, loss: -0.43352
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 11 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0012.pth
# 0012
# Starting Training
# epoch: 00, loss: -0.38514
# epoch: 01, loss: -0.38745
# epoch: 02, loss: -0.38612
# epoch: 03, loss: -0.38668
# epoch: 04, loss: -0.38613
# epoch: 05, loss: -0.38631
# epoch: 06, loss: -0.38651
# epoch: 07, loss: -0.38643
# epoch: 08, loss: -0.38585
# epoch: 09, loss: -0.38561
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   1%|          | 12/1000 [03:44<5:00:26, 18.25s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 12 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0013.pth
# 0013
# Starting Training
# epoch: 00, loss: -0.37619
# epoch: 01, loss: -0.35955
# epoch: 02, loss: -0.36288
# epoch: 03, loss: -0.36767
# epoch: 04, loss: -0.37250
# epoch: 05, loss: -0.37691
# epoch: 06, loss: -0.38092
# epoch: 07, loss: -0.38492
# epoch: 08, loss: -0.38876
# epoch: 09, loss: -0.39249
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   1%|▏         | 13/1000 [04:02<4:58:35, 18.15s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 13 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0014.pth
# 0014
# Starting Training
# epoch: 00, loss: -0.35184
# epoch: 01, loss: -0.35221
# epoch: 02, loss: -0.35486
# epoch: 03, loss: -0.35704
# epoch: 04, loss: -0.35817
# epoch: 05, loss: -0.36029
# epoch: 06, loss: -0.36209
# epoch: 07, loss: -0.36453
# epoch: 08, loss: -0.36533
# epoch: 09, loss: -0.36896
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   1%|▏         | 14/1000 [04:21<5:02:30, 18.41s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 14 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0015.pth
# 0015
# Starting Training
# epoch: 00, loss: -0.42612
# epoch: 01, loss: -0.42452
# epoch: 02, loss: -0.41929
# epoch: 03, loss: -0.41900
# epoch: 04, loss: -0.42130
# epoch: 05, loss: -0.42667
# epoch: 06, loss: -0.43243
# epoch: 07, loss: -0.43754
# epoch: 08, loss: -0.44112
# epoch: 09, loss: -0.44391
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   2%|▏         | 15/1000 [04:40<5:03:20, 18.48s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 15 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0016.pth
# 0016
# Starting Training
# epoch: 00, loss: -0.42657
# epoch: 01, loss: -0.43816
# epoch: 02, loss: -0.43733
# epoch: 03, loss: -0.43875
# epoch: 04, loss: -0.44049
# epoch: 05, loss: -0.44359
# epoch: 06, loss: -0.44601
# epoch: 07, loss: -0.44877
# epoch: 08, loss: -0.44930
# epoch: 09, loss: -0.45095
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   2%|▏         | 16/1000 [04:58<5:01:37, 18.39s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 16 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0017.pth
# 0017
# Starting Training
# epoch: 00, loss: -0.38094
# epoch: 01, loss: -0.39128
# epoch: 02, loss: -0.39106
# epoch: 03, loss: -0.38948
# epoch: 04, loss: -0.38790
# epoch: 05, loss: -0.38749
# epoch: 06, loss: -0.38674
# epoch: 07, loss: -0.38799
# epoch: 08, loss: -0.38932
# epoch: 09, loss: -0.39080
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   2%|▏         | 17/1000 [05:17<5:04:53, 18.61s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 17 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0018.pth
# 0018
# Starting Training
# epoch: 00, loss: -0.40219
# epoch: 01, loss: -0.41096
# epoch: 02, loss: -0.41430
# epoch: 03, loss: -0.41790
# epoch: 04, loss: -0.42120
# epoch: 05, loss: -0.42397
# epoch: 06, loss: -0.42740
# epoch: 07, loss: -0.43325
# epoch: 08, loss: -0.43616
# epoch: 09, loss: -0.43998
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   2%|▏         | 18/1000 [05:36<5:06:07, 18.70s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 18 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0019.pth
# 0019
# Starting Training
# epoch: 00, loss: -0.36411
# epoch: 01, loss: -0.37484
# epoch: 02, loss: -0.37911
# epoch: 03, loss: -0.38159
# epoch: 04, loss: -0.38404
# epoch: 05, loss: -0.38637
# epoch: 06, loss: -0.38845
# epoch: 07, loss: -0.39012
# epoch: 08, loss: -0.39182
#   2%|▏         | 19/1000 [05:56<5:10:00, 18.96s/it]
# epoch: 09, loss: -0.39256
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 19 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0020.pth
# 0020
# Starting Training
# epoch: 00, loss: -0.40770
# epoch: 01, loss: -0.40757
# epoch: 02, loss: -0.40069
# epoch: 03, loss: -0.39244
# epoch: 04, loss: -0.39152
# epoch: 05, loss: -0.39223
# epoch: 06, loss: -0.39254
# epoch: 07, loss: -0.39220
# epoch: 08, loss: -0.39275
#   2%|▏         | 20/1000 [06:16<5:18:47, 19.52s/it]
# epoch: 09, loss: -0.39343
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 20 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0021.pth
# 0021
# Starting Training
# epoch: 00, loss: -0.38980
# epoch: 01, loss: -0.38994
# epoch: 02, loss: -0.39554
# epoch: 03, loss: -0.40220
# epoch: 04, loss: -0.40747
# epoch: 05, loss: -0.41251
# epoch: 06, loss: -0.41500
# epoch: 07, loss: -0.41731
# epoch: 08, loss: -0.41859
#   2%|▏         | 21/1000 [06:38<5:30:06, 20.23s/it]
# epoch: 09, loss: -0.42013
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 21 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0022.pth
# 0022
# Starting Training
# epoch: 00, loss: -0.38905
# epoch: 01, loss: -0.40121
# epoch: 02, loss: -0.40353
# epoch: 03, loss: -0.40785
# epoch: 04, loss: -0.41257
# epoch: 05, loss: -0.41627
# epoch: 06, loss: -0.41976
# epoch: 07, loss: -0.42313
# epoch: 08, loss: -0.42440
#   2%|▏         | 22/1000 [06:56<5:16:58, 19.45s/it]
# epoch: 09, loss: -0.42858
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 22 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0023.pth
# 0023
# Starting Training
# epoch: 00, loss: -0.36775
# epoch: 01, loss: -0.37792
# epoch: 02, loss: -0.38155
# epoch: 03, loss: -0.38657
# epoch: 04, loss: -0.39004
# epoch: 05, loss: -0.39421
# epoch: 06, loss: -0.39904
# epoch: 07, loss: -0.40387
# epoch: 08, loss: -0.40842
# epoch: 09, loss: -0.41525
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   2%|▏         | 23/1000 [07:17<5:23:13, 19.85s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 23 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0024.pth
# 0024
# Starting Training
# epoch: 00, loss: -0.58009
# epoch: 01, loss: -0.60218
# epoch: 02, loss: -0.60355
# epoch: 03, loss: -0.60425
# epoch: 04, loss: -0.60506
# epoch: 05, loss: -0.60585
# epoch: 06, loss: -0.60598
# epoch: 07, loss: -0.60651
# epoch: 08, loss: -0.60706
#   2%|▏         | 24/1000 [07:35<5:14:54, 19.36s/it]
# epoch: 09, loss: -0.60726
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 24 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0025.pth
# 0025
# Starting Training
# epoch: 00, loss: -0.36656
# epoch: 01, loss: -0.36810
# epoch: 02, loss: -0.37025
# epoch: 03, loss: -0.37115
# epoch: 04, loss: -0.37330
# epoch: 05, loss: -0.37664
# epoch: 06, loss: -0.37594
# epoch: 07, loss: -0.37756
# epoch: 08, loss: -0.37757
#   2%|▎         | 25/1000 [07:53<5:07:41, 18.94s/it]
# epoch: 09, loss: -0.37840
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 25 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0026.pth
# 0026
# Starting Training
# epoch: 00, loss: -0.37402
# epoch: 01, loss: -0.37434
# epoch: 02, loss: -0.37277
# epoch: 03, loss: -0.37136
# epoch: 04, loss: -0.37154
# epoch: 05, loss: -0.37436
# epoch: 06, loss: -0.37901
# epoch: 07, loss: -0.38393
# epoch: 08, loss: -0.39168
#   3%|▎         | 26/1000 [08:10<4:59:59, 18.48s/it]
# epoch: 09, loss: -0.40001
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 26 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0027.pth
# 0027
# Starting Training
# epoch: 00, loss: -0.38030
# epoch: 01, loss: -0.38016
# epoch: 02, loss: -0.38233
# epoch: 03, loss: -0.38305
# epoch: 04, loss: -0.38302
# epoch: 05, loss: -0.38275
# epoch: 06, loss: -0.38401
# epoch: 07, loss: -0.38351
# epoch: 08, loss: -0.38386
#   3%|▎         | 27/1000 [08:28<4:53:49, 18.12s/it]
# epoch: 09, loss: -0.38401
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 27 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0028.pth
# 0028
# Starting Training
# epoch: 00, loss: -0.37744
# epoch: 01, loss: -0.38687
# epoch: 02, loss: -0.39017
# epoch: 03, loss: -0.39377
# epoch: 04, loss: -0.39488
# epoch: 05, loss: -0.39676
# epoch: 06, loss: -0.39789
# epoch: 07, loss: -0.39917
# epoch: 08, loss: -0.40019
# epoch: 09, loss: -0.40101
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   3%|▎         | 28/1000 [08:48<5:05:45, 18.87s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 28 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0029.pth
# 0029
# Starting Training
# epoch: 00, loss: -0.40053
# epoch: 01, loss: -0.42079
# epoch: 02, loss: -0.42386
# epoch: 03, loss: -0.42512
# epoch: 04, loss: -0.42517
# epoch: 05, loss: -0.42421
# epoch: 06, loss: -0.42419
# epoch: 07, loss: -0.42409
# epoch: 08, loss: -0.42370
#   3%|▎         | 29/1000 [09:07<5:07:08, 18.98s/it]
# epoch: 09, loss: -0.42256
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 29 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0030.pth
# 0030
# Starting Training
# epoch: 00, loss: -0.40210
# epoch: 01, loss: -0.41251
# epoch: 02, loss: -0.41409
# epoch: 03, loss: -0.41475
# epoch: 04, loss: -0.41630
# epoch: 05, loss: -0.41677
# epoch: 06, loss: -0.41918
# epoch: 07, loss: -0.42086
# epoch: 08, loss: -0.42216
# epoch: 09, loss: -0.42396
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   3%|▎         | 30/1000 [09:27<5:08:44, 19.10s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 30 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0031.pth
# 0031
# Starting Training
# epoch: 00, loss: -0.41221
# epoch: 01, loss: -0.40579
# epoch: 02, loss: -0.40225
# epoch: 03, loss: -0.40405
# epoch: 04, loss: -0.40440
# epoch: 05, loss: -0.40537
# epoch: 06, loss: -0.40675
# epoch: 07, loss: -0.40728
# epoch: 08, loss: -0.40786
# epoch: 09, loss: -0.40827
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   3%|▎         | 31/1000 [09:45<5:01:38, 18.68s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 31 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0032.pth
# 0032
# Starting Training
# epoch: 00, loss: -0.60849
# epoch: 01, loss: -0.63121
# epoch: 02, loss: -0.63336
# epoch: 03, loss: -0.63525
# epoch: 04, loss: -0.63629
# epoch: 05, loss: -0.63741
# epoch: 06, loss: -0.63851
# epoch: 07, loss: -0.63904
# epoch: 08, loss: -0.64008
# epoch: 09, loss: -0.64071
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   3%|▎         | 32/1000 [10:03<5:02:05, 18.72s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 32 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0033.pth
# 0033
# Starting Training
# epoch: 00, loss: -0.40434
# epoch: 01, loss: -0.41657
# epoch: 02, loss: -0.41482
# epoch: 03, loss: -0.41558
# epoch: 04, loss: -0.41458
# epoch: 05, loss: -0.41573
# epoch: 06, loss: -0.41626
# epoch: 07, loss: -0.41708
# epoch: 08, loss: -0.41819
# epoch: 09, loss: -0.41943
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   3%|▎         | 33/1000 [10:22<5:01:51, 18.73s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 33 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0034.pth
# 0034
# Starting Training
# epoch: 00, loss: -0.39005
# epoch: 01, loss: -0.40352
# epoch: 02, loss: -0.40911
# epoch: 03, loss: -0.41404
# epoch: 04, loss: -0.41929
# epoch: 05, loss: -0.42129
# epoch: 06, loss: -0.42665
# epoch: 07, loss: -0.43116
# epoch: 08, loss: -0.43662
# epoch: 09, loss: -0.44304
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   3%|▎         | 34/1000 [10:38<4:49:25, 17.98s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 34 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0035.pth
# 0035
# Starting Training
# epoch: 00, loss: -0.40724
# epoch: 01, loss: -0.41283
# epoch: 02, loss: -0.41067
# epoch: 03, loss: -0.41032
# epoch: 04, loss: -0.40997
# epoch: 05, loss: -0.41001
# epoch: 06, loss: -0.41118
# epoch: 07, loss: -0.41168
# epoch: 08, loss: -0.41136
# epoch: 09, loss: -0.41157
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   4%|▎         | 35/1000 [10:56<4:47:17, 17.86s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 35 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0036.pth
# 0036
# Starting Training
# epoch: 00, loss: -0.39530
# epoch: 01, loss: -0.40127
# epoch: 02, loss: -0.40274
# epoch: 03, loss: -0.40297
# epoch: 04, loss: -0.40282
# epoch: 05, loss: -0.40295
# epoch: 06, loss: -0.40399
# epoch: 07, loss: -0.40409
# epoch: 08, loss: -0.40491
# epoch: 09, loss: -0.40477
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   4%|▎         | 36/1000 [11:18<5:07:02, 19.11s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 36 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0037.pth
# 0037
# Starting Training
# epoch: 00, loss: -0.39061
# epoch: 01, loss: -0.39721
# epoch: 02, loss: -0.40158
# epoch: 03, loss: -0.40494
# epoch: 04, loss: -0.40930
# epoch: 05, loss: -0.41250
# epoch: 06, loss: -0.41660
# epoch: 07, loss: -0.42070
# epoch: 08, loss: -0.42438
# epoch: 09, loss: -0.42946
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   4%|▎         | 37/1000 [11:38<5:10:47, 19.36s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 37 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0038.pth
# 0038
# Starting Training
# epoch: 00, loss: -0.35808
# epoch: 01, loss: -0.36700
# epoch: 02, loss: -0.37058
# epoch: 03, loss: -0.37385
# epoch: 04, loss: -0.37596
# epoch: 05, loss: -0.37764
# epoch: 06, loss: -0.37939
# epoch: 07, loss: -0.38113
# epoch: 08, loss: -0.38340
# epoch: 09, loss: -0.38434
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   4%|▍         | 38/1000 [11:59<5:17:46, 19.82s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 38 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0039.pth
# 0039
# Starting Training
# epoch: 00, loss: -0.40663
# epoch: 01, loss: -0.42817
# epoch: 02, loss: -0.43179
# epoch: 03, loss: -0.43455
# epoch: 04, loss: -0.43652
# epoch: 05, loss: -0.43758
# epoch: 06, loss: -0.43862
# epoch: 07, loss: -0.43924
# epoch: 08, loss: -0.44033
# epoch: 09, loss: -0.44000
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   4%|▍         | 39/1000 [12:20<5:25:24, 20.32s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 39 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0040.pth
# 0040
# Starting Training
# epoch: 00, loss: -0.37430
# epoch: 01, loss: -0.36669
# epoch: 02, loss: -0.36731
# epoch: 03, loss: -0.36797
# epoch: 04, loss: -0.37381
# epoch: 05, loss: -0.38477
# epoch: 06, loss: -0.39439
# epoch: 07, loss: -0.40115
# epoch: 08, loss: -0.40609
# epoch: 09, loss: -0.40853
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   4%|▍         | 40/1000 [12:39<5:17:57, 19.87s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 40 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0041.pth
# 0041
# Starting Training
# epoch: 00, loss: -0.35779
# epoch: 01, loss: -0.36325
# epoch: 02, loss: -0.36918
# epoch: 03, loss: -0.38123
# epoch: 04, loss: -0.38593
# epoch: 05, loss: -0.39611
# epoch: 06, loss: -0.40236
# epoch: 07, loss: -0.40462
# epoch: 08, loss: -0.40650
# epoch: 09, loss: -0.40970
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   4%|▍         | 41/1000 [13:00<5:23:11, 20.22s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 41 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0042.pth
# 0042
# Starting Training
# epoch: 00, loss: -0.41712
# epoch: 01, loss: -0.43028
# epoch: 02, loss: -0.43171
# epoch: 03, loss: -0.43172
# epoch: 04, loss: -0.43288
# epoch: 05, loss: -0.43321
# epoch: 06, loss: -0.43372
# epoch: 07, loss: -0.43531
# epoch: 08, loss: -0.43572
# epoch: 09, loss: -0.43635
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   4%|▍         | 42/1000 [13:19<5:15:24, 19.75s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 42 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0043.pth
# 0043
# Starting Training
# epoch: 00, loss: -0.37337
# epoch: 01, loss: -0.37294
# epoch: 02, loss: -0.39126
# epoch: 03, loss: -0.41044
# epoch: 04, loss: -0.42975
# epoch: 05, loss: -0.44375
# epoch: 06, loss: -0.45513
# epoch: 07, loss: -0.46310
# epoch: 08, loss: -0.47040
# epoch: 09, loss: -0.47555
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   4%|▍         | 43/1000 [13:40<5:22:01, 20.19s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 43 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0044.pth
# 0044
# Starting Training
# epoch: 00, loss: -0.49235
# epoch: 01, loss: -0.50478
# epoch: 02, loss: -0.51207
# epoch: 03, loss: -0.51706
# epoch: 04, loss: -0.52167
# epoch: 05, loss: -0.52647
# epoch: 06, loss: -0.53081
# epoch: 07, loss: -0.53487
# epoch: 08, loss: -0.53767
#   4%|▍         | 44/1000 [14:05<5:42:31, 21.50s/it]
# epoch: 09, loss: -0.54071
# After Unsqueezing, feature size= torch.Size([525, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([525, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 525])
# 44 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0045.pth
# 0045
# Starting Training
# epoch: 00, loss: -0.39370
# epoch: 01, loss: -0.40289
# epoch: 02, loss: -0.40524
# epoch: 03, loss: -0.40633
# epoch: 04, loss: -0.40897
# epoch: 05, loss: -0.41019
# epoch: 06, loss: -0.41148
# epoch: 07, loss: -0.41227
# epoch: 08, loss: -0.41283
#   4%|▍         | 45/1000 [14:28<5:49:47, 21.98s/it]
# epoch: 09, loss: -0.41302
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 45 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0046.pth
# 0046
# Starting Training
# epoch: 00, loss: -0.34652
# epoch: 01, loss: -0.33831
# epoch: 02, loss: -0.33948
# epoch: 03, loss: -0.34219
# epoch: 04, loss: -0.34375
# epoch: 05, loss: -0.34614
# epoch: 06, loss: -0.34845
# epoch: 07, loss: -0.35106
# epoch: 08, loss: -0.35315
# epoch: 09, loss: -0.35515
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
#   5%|▍         | 46/1000 [14:51<5:58:07, 22.52s/it]
# 46 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0047.pth
# 0047
# Starting Training
# epoch: 00, loss: -0.36738
# epoch: 01, loss: -0.38329
# epoch: 02, loss: -0.38158
# epoch: 03, loss: -0.38016
# epoch: 04, loss: -0.37968
# epoch: 05, loss: -0.37687
# epoch: 06, loss: -0.37668
# epoch: 07, loss: -0.37787
# epoch: 08, loss: -0.37740
#   5%|▍         | 47/1000 [15:10<5:37:21, 21.24s/it]
# epoch: 09, loss: -0.37812
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 47 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0048.pth
# 0048
# Starting Training
# epoch: 00, loss: -0.40591
# epoch: 01, loss: -0.41121
# epoch: 02, loss: -0.40890
# epoch: 03, loss: -0.40518
# epoch: 04, loss: -0.40076
# epoch: 05, loss: -0.39538
# epoch: 06, loss: -0.39159
# epoch: 07, loss: -0.39162
# epoch: 08, loss: -0.39195
# epoch: 09, loss: -0.39324
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   5%|▍         | 48/1000 [15:33<5:44:51, 21.73s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 48 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0049.pth
# 0049
# Starting Training
# epoch: 00, loss: -0.35866
# epoch: 01, loss: -0.36522
# epoch: 02, loss: -0.36883
# epoch: 03, loss: -0.37025
# epoch: 04, loss: -0.37138
# epoch: 05, loss: -0.37096
# epoch: 06, loss: -0.37224
# epoch: 07, loss: -0.37301
# epoch: 08, loss: -0.37402
# epoch: 09, loss: -0.37524
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   5%|▍         | 49/1000 [15:54<5:42:58, 21.64s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 49 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0050.pth
# 0050
# Starting Training
# epoch: 00, loss: -0.39023
# epoch: 01, loss: -0.39043
# epoch: 02, loss: -0.39306
# epoch: 03, loss: -0.39486
# epoch: 04, loss: -0.39608
# epoch: 05, loss: -0.39738
# epoch: 06, loss: -0.39890
# epoch: 07, loss: -0.39857
# epoch: 08, loss: -0.40034
# epoch: 09, loss: -0.40088
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   5%|▌         | 50/1000 [16:14<5:34:27, 21.12s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 50 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0051.pth
# 0051
# Starting Training
# epoch: 00, loss: -0.42725
# epoch: 01, loss: -0.41836
# epoch: 02, loss: -0.41579
# epoch: 03, loss: -0.41620
# epoch: 04, loss: -0.41816
# epoch: 05, loss: -0.42067
# epoch: 06, loss: -0.42249
# epoch: 07, loss: -0.42497
# epoch: 08, loss: -0.42699
# epoch: 09, loss: -0.42882
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   5%|▌         | 51/1000 [16:39<5:54:39, 22.42s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 51 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0052.pth
# 0052
# Starting Training
# epoch: 00, loss: -0.38665
# epoch: 01, loss: -0.39086
# epoch: 02, loss: -0.39147
# epoch: 03, loss: -0.38967
# epoch: 04, loss: -0.39007
# epoch: 05, loss: -0.38949
# epoch: 06, loss: -0.38891
# epoch: 07, loss: -0.38766
# epoch: 08, loss: -0.38800
#   5%|▌         | 52/1000 [17:04<6:03:16, 22.99s/it]
# epoch: 09, loss: -0.38740
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 52 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0053.pth
# 0053
# Starting Training
# epoch: 00, loss: -0.41297
# epoch: 01, loss: -0.42567
# epoch: 02, loss: -0.42431
# epoch: 03, loss: -0.42390
# epoch: 04, loss: -0.42365
# epoch: 05, loss: -0.42391
# epoch: 06, loss: -0.42395
# epoch: 07, loss: -0.42465
# epoch: 08, loss: -0.42546
# epoch: 09, loss: -0.42479
# After Unsqueezing, feature size= torch.Size([375, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([375, 384])
#   5%|▌         | 53/1000 [17:25<5:54:11, 22.44s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 375])
# 53 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0054.pth
# 0054
# Starting Training
# epoch: 00, loss: -0.64646
# epoch: 01, loss: -0.70359
# epoch: 02, loss: -0.70462
# epoch: 03, loss: -0.70529
# epoch: 04, loss: -0.70555
# epoch: 05, loss: -0.70612
# epoch: 06, loss: -0.70630
# epoch: 07, loss: -0.70694
# epoch: 08, loss: -0.70712
# epoch: 09, loss: -0.70733
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   5%|▌         | 54/1000 [17:45<5:42:27, 21.72s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 54 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0055.pth
# 0055
# Starting Training
# epoch: 00, loss: -0.40446
# epoch: 01, loss: -0.42336
# epoch: 02, loss: -0.42148
# epoch: 03, loss: -0.42064
# epoch: 04, loss: -0.41944
# epoch: 05, loss: -0.41771
# epoch: 06, loss: -0.41567
# epoch: 07, loss: -0.41418
# epoch: 08, loss: -0.41202
#   6%|▌         | 55/1000 [18:06<5:37:19, 21.42s/it]
# epoch: 09, loss: -0.41097
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 55 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0056.pth
# 0056
# Starting Training
# epoch: 00, loss: -0.40481
# epoch: 01, loss: -0.41364
# epoch: 02, loss: -0.41571
# epoch: 03, loss: -0.41800
# epoch: 04, loss: -0.42084
# epoch: 05, loss: -0.42436
# epoch: 06, loss: -0.42694
# epoch: 07, loss: -0.43029
# epoch: 08, loss: -0.43263
# epoch: 09, loss: -0.43471
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   6%|▌         | 56/1000 [18:23<5:17:18, 20.17s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 56 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0057.pth
# 0057
# Starting Training
# epoch: 00, loss: -0.40100
# epoch: 01, loss: -0.40962
# epoch: 02, loss: -0.41340
# epoch: 03, loss: -0.41672
# epoch: 04, loss: -0.41790
# epoch: 05, loss: -0.42022
# epoch: 06, loss: -0.42308
# epoch: 07, loss: -0.42643
# epoch: 08, loss: -0.42902
# epoch: 09, loss: -0.43267
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   6%|▌         | 57/1000 [18:43<5:14:51, 20.03s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 57 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0058.pth
# 0058
# Starting Training
# epoch: 00, loss: -0.37477
# epoch: 01, loss: -0.37874
# epoch: 02, loss: -0.37960
# epoch: 03, loss: -0.38061
# epoch: 04, loss: -0.38148
# epoch: 05, loss: -0.38262
# epoch: 06, loss: -0.38443
# epoch: 07, loss: -0.38538
# epoch: 08, loss: -0.38520
# epoch: 09, loss: -0.38614
# After Unsqueezing, feature size= torch.Size([425, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([425, 384])
#   6%|▌         | 58/1000 [19:04<5:21:57, 20.51s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 425])
# 58 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0059.pth
# 0059
# Starting Training
# epoch: 00, loss: -0.41310
# epoch: 01, loss: -0.42214
# epoch: 02, loss: -0.42479
# epoch: 03, loss: -0.42371
# epoch: 04, loss: -0.42502
# epoch: 05, loss: -0.42578
# epoch: 06, loss: -0.42772
# epoch: 07, loss: -0.42886
# epoch: 08, loss: -0.43035
# epoch: 09, loss: -0.43107
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   6%|▌         | 59/1000 [19:26<5:29:06, 20.99s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 59 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0060.pth
# 0060
# Starting Training
# epoch: 00, loss: -0.39557
# epoch: 01, loss: -0.41218
# epoch: 02, loss: -0.41280
# epoch: 03, loss: -0.41472
# epoch: 04, loss: -0.41591
# epoch: 05, loss: -0.41683
# epoch: 06, loss: -0.41591
# epoch: 07, loss: -0.41465
# epoch: 08, loss: -0.41512
# epoch: 09, loss: -0.41651
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   6%|▌         | 60/1000 [19:50<5:40:06, 21.71s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 60 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0061.pth
# 0061
# Starting Training
# epoch: 00, loss: -0.38946
# epoch: 01, loss: -0.39147
# epoch: 02, loss: -0.39396
# epoch: 03, loss: -0.39569
# epoch: 04, loss: -0.39675
# epoch: 05, loss: -0.39705
# epoch: 06, loss: -0.39654
# epoch: 07, loss: -0.39548
# epoch: 08, loss: -0.39583
# epoch: 09, loss: -0.39689
# After Unsqueezing, feature size= torch.Size([425, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([425, 384])
#   6%|▌         | 61/1000 [20:13<5:45:52, 22.10s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 425])
# 61 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0062.pth
# 0062
# Starting Training
# epoch: 00, loss: -0.37758
# epoch: 01, loss: -0.37114
# epoch: 02, loss: -0.37223
# epoch: 03, loss: -0.37631
# epoch: 04, loss: -0.38067
# epoch: 05, loss: -0.38451
# epoch: 06, loss: -0.38932
# epoch: 07, loss: -0.39338
# epoch: 08, loss: -0.39746
# epoch: 09, loss: -0.40189
# After Unsqueezing, feature size= torch.Size([425, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([425, 384])
#   6%|▌         | 62/1000 [20:40<6:09:32, 23.64s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 425])
# 62 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0063.pth
# 0063
# Starting Training
# epoch: 00, loss: -0.45850
# epoch: 01, loss: -0.45948
# epoch: 02, loss: -0.45708
# epoch: 03, loss: -0.45631
# epoch: 04, loss: -0.45735
# epoch: 05, loss: -0.45892
# epoch: 06, loss: -0.46068
# epoch: 07, loss: -0.46155
# epoch: 08, loss: -0.46233
# epoch: 09, loss: -0.46316
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   6%|▋         | 63/1000 [21:05<6:15:59, 24.08s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 63 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0064.pth
# 0064
# Starting Training
# epoch: 00, loss: -0.39890
# epoch: 01, loss: -0.40913
# epoch: 02, loss: -0.41116
# epoch: 03, loss: -0.41296
# epoch: 04, loss: -0.41428
# epoch: 05, loss: -0.41717
# epoch: 06, loss: -0.41778
# epoch: 07, loss: -0.41917
# epoch: 08, loss: -0.42089
# epoch: 09, loss: -0.42238
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   6%|▋         | 64/1000 [21:31<6:25:10, 24.69s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 64 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0065.pth
# 0065
# Starting Training
# epoch: 00, loss: -0.40471
# epoch: 01, loss: -0.41515
# epoch: 02, loss: -0.41778
# epoch: 03, loss: -0.42023
# epoch: 04, loss: -0.42194
# epoch: 05, loss: -0.42320
# epoch: 06, loss: -0.42225
# epoch: 07, loss: -0.42410
# epoch: 08, loss: -0.42473
# epoch: 09, loss: -0.42578
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#   6%|▋         | 65/1000 [21:57<6:29:11, 24.98s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 65 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0066.pth
# 0066
# Starting Training
# epoch: 00, loss: -0.40979
# epoch: 01, loss: -0.42435
# epoch: 02, loss: -0.42872
# epoch: 03, loss: -0.43230
# epoch: 04, loss: -0.43752
# epoch: 05, loss: -0.44125
# epoch: 06, loss: -0.44509
# epoch: 07, loss: -0.44676
# epoch: 08, loss: -0.45335
# epoch: 09, loss: -0.45484
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#   7%|▋         | 66/1000 [22:18<6:10:35, 23.81s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 66 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0067.pth
# 0067
# Starting Training
# epoch: 00, loss: -0.41143
# epoch: 01, loss: -0.43001
# epoch: 02, loss: -0.43222
# epoch: 03, loss: -0.43420
# epoch: 04, loss: -0.43605
# epoch: 05, loss: -0.43870
# epoch: 06, loss: -0.44162
# epoch: 07, loss: -0.44393
# epoch: 08, loss: -0.44700
# epoch: 09, loss: -0.45037
# After Unsqueezing, feature size= torch.Size([350, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([350, 384])
#   7%|▋         | 67/1000 [22:35<5:38:51, 21.79s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 350])
# 67 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0068.pth
# 0068
# Starting Training
# epoch: 00, loss: -0.40296
# epoch: 01, loss: -0.41088
# epoch: 02, loss: -0.41158
# epoch: 03, loss: -0.41044
# epoch: 04, loss: -0.40916
# epoch: 05, loss: -0.40624
# epoch: 06, loss: -0.40286
# epoch: 07, loss: -0.40009
# epoch: 08, loss: -0.39701
# epoch: 09, loss: -0.39408
# After Unsqueezing, feature size= torch.Size([525, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([525, 384])
#   7%|▋         | 68/1000 [23:04<6:14:15, 24.09s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 525])
# 68 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0069.pth
# 0069
# Starting Training
# epoch: 00, loss: -0.38902
# epoch: 01, loss: -0.39795
# epoch: 02, loss: -0.40175
# epoch: 03, loss: -0.40705
# epoch: 04, loss: -0.41242
# epoch: 05, loss: -0.41739
# epoch: 06, loss: -0.42159
# epoch: 07, loss: -0.42428
# epoch: 08, loss: -0.42698
# epoch: 09, loss: -0.42946
# After Unsqueezing, feature size= torch.Size([425, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([425, 384])
#   7%|▋         | 69/1000 [23:27<6:08:31, 23.75s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 425])
# 69 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0070.pth
# 0070
# Starting Training
# epoch: 00, loss: -0.40475
# epoch: 01, loss: -0.41643
# epoch: 02, loss: -0.41700
# epoch: 03, loss: -0.41618
# epoch: 04, loss: -0.41663
# epoch: 05, loss: -0.41650
# epoch: 06, loss: -0.41593
# epoch: 07, loss: -0.41463
# epoch: 08, loss: -0.41285
# epoch: 09, loss: -0.41147
# After Unsqueezing, feature size= torch.Size([500, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([500, 384])
#   7%|▋         | 70/1000 [23:55<6:28:05, 25.04s/it]
# ...
# projected feature shape= torch.Size([525, 384])
#  98%|█████████▊| 977/1000 [6:51:50<10:13, 26.69s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 525])
# 977 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0978.pth
# 0978
# Starting Training
# epoch: 00, loss: -0.44151
# epoch: 01, loss: -0.43149
# epoch: 02, loss: -0.43168
# epoch: 03, loss: -0.43782
# epoch: 04, loss: -0.44504
# epoch: 05, loss: -0.45036
# epoch: 06, loss: -0.45592
# epoch: 07, loss: -0.46034
# epoch: 08, loss: -0.46301
# epoch: 09, loss: -0.46673
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  98%|█████████▊| 978/1000 [6:52:13<09:21, 25.52s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 978 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0979.pth
# 0979
# Starting Training
# epoch: 00, loss: -0.42186
# epoch: 01, loss: -0.43914
# epoch: 02, loss: -0.44215
# epoch: 03, loss: -0.44670
# epoch: 04, loss: -0.44809
# epoch: 05, loss: -0.45091
# epoch: 06, loss: -0.45226
# epoch: 07, loss: -0.45359
# epoch: 08, loss: -0.45664
# epoch: 09, loss: -0.45899
# After Unsqueezing, feature size= torch.Size([525, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([525, 384])
#  98%|█████████▊| 979/1000 [6:52:40<09:08, 26.12s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 525])
# 979 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0980.pth
# 0980
# Starting Training
# epoch: 00, loss: -0.38778
# epoch: 01, loss: -0.39548
# epoch: 02, loss: -0.39490
# epoch: 03, loss: -0.39455
# epoch: 04, loss: -0.39400
# epoch: 05, loss: -0.39166
# epoch: 06, loss: -0.38960
# epoch: 07, loss: -0.38776
# epoch: 08, loss: -0.38809
# epoch: 09, loss: -0.38534
# After Unsqueezing, feature size= torch.Size([550, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([550, 384])
#  98%|█████████▊| 980/1000 [6:53:13<09:21, 28.07s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 550])
# 980 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0981.pth
# 0981
# Starting Training
# epoch: 00, loss: -0.39122
# epoch: 01, loss: -0.40260
# epoch: 02, loss: -0.40582
# epoch: 03, loss: -0.40743
# epoch: 04, loss: -0.40995
# epoch: 05, loss: -0.41210
# epoch: 06, loss: -0.41328
# epoch: 07, loss: -0.41528
# epoch: 08, loss: -0.41775
# epoch: 09, loss: -0.42052
# After Unsqueezing, feature size= torch.Size([600, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([600, 384])
#  98%|█████████▊| 981/1000 [6:53:51<09:50, 31.11s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 600])
# 981 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0982.pth
# 0982
# Starting Training
# epoch: 00, loss: -0.38941
# epoch: 01, loss: -0.39519
# epoch: 02, loss: -0.39626
# epoch: 03, loss: -0.39556
# epoch: 04, loss: -0.39318
# epoch: 05, loss: -0.39047
# epoch: 06, loss: -0.38786
# epoch: 07, loss: -0.38691
# epoch: 08, loss: -0.38752
# epoch: 09, loss: -0.38849
# After Unsqueezing, feature size= torch.Size([408, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([408, 384])
#  98%|█████████▊| 982/1000 [6:54:17<08:51, 29.52s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 408])
# 982 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0983.pth
# 0983
# Starting Training
# epoch: 00, loss: -0.58334
# epoch: 01, loss: -0.61058
# epoch: 02, loss: -0.61140
# epoch: 03, loss: -0.61233
# epoch: 04, loss: -0.61282
# epoch: 05, loss: -0.61329
# epoch: 06, loss: -0.61366
# epoch: 07, loss: -0.61359
# epoch: 08, loss: -0.61379
# epoch: 09, loss: -0.61404
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  98%|█████████▊| 983/1000 [6:54:40<07:50, 27.68s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 983 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0984.pth
# 0984
# Starting Training
# epoch: 00, loss: -0.39422
# epoch: 01, loss: -0.39194
# epoch: 02, loss: -0.38122
# epoch: 03, loss: -0.37708
# epoch: 04, loss: -0.37261
# epoch: 05, loss: -0.37025
# epoch: 06, loss: -0.36889
# epoch: 07, loss: -0.36895
# epoch: 08, loss: -0.37059
# epoch: 09, loss: -0.37085
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  98%|█████████▊| 984/1000 [6:55:06<07:12, 27.00s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 984 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0985.pth
# 0985
# Starting Training
# epoch: 00, loss: -0.39686
# epoch: 01, loss: -0.41424
# epoch: 02, loss: -0.43053
# epoch: 03, loss: -0.44319
# epoch: 04, loss: -0.45261
# epoch: 05, loss: -0.45806
# epoch: 06, loss: -0.46192
# epoch: 07, loss: -0.46484
# epoch: 08, loss: -0.46818
# epoch: 09, loss: -0.46891
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  98%|█████████▊| 985/1000 [6:55:31<06:39, 26.61s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 985 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0986.pth
# 0986
# Starting Training
# epoch: 00, loss: -0.56715
# epoch: 01, loss: -0.57884
# epoch: 02, loss: -0.58486
# epoch: 03, loss: -0.58953
# epoch: 04, loss: -0.59313
# epoch: 05, loss: -0.59587
# epoch: 06, loss: -0.59836
# epoch: 07, loss: -0.60000
# epoch: 08, loss: -0.60144
# epoch: 09, loss: -0.60306
# After Unsqueezing, feature size= torch.Size([375, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([375, 384])
#  99%|█████████▊| 986/1000 [6:55:54<05:55, 25.40s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 375])
# 986 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0987.pth
# 0987
# Starting Training
# epoch: 00, loss: -0.44609
# epoch: 01, loss: -0.45456
# epoch: 02, loss: -0.45861
# epoch: 03, loss: -0.46244
# epoch: 04, loss: -0.46575
# epoch: 05, loss: -0.46853
# epoch: 06, loss: -0.47083
# epoch: 07, loss: -0.47297
# epoch: 08, loss: -0.47489
# epoch: 09, loss: -0.47635
# After Unsqueezing, feature size= torch.Size([425, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([425, 384])
#  99%|█████████▊| 987/1000 [6:56:18<05:25, 25.05s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 425])
# 987 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0988.pth
# 0988
# Starting Training
# epoch: 00, loss: -0.38148
# epoch: 01, loss: -0.38242
# epoch: 02, loss: -0.38381
# epoch: 03, loss: -0.38504
# epoch: 04, loss: -0.38687
# epoch: 05, loss: -0.38722
# epoch: 06, loss: -0.38896
# epoch: 07, loss: -0.38941
# epoch: 08, loss: -0.39020
# epoch: 09, loss: -0.39160
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  99%|█████████▉| 988/1000 [6:56:45<05:06, 25.56s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 988 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0989.pth
# 0989
# Starting Training
# epoch: 00, loss: -0.46567
# epoch: 01, loss: -0.47034
# epoch: 02, loss: -0.47694
# epoch: 03, loss: -0.48239
# epoch: 04, loss: -0.48728
# epoch: 05, loss: -0.49293
# epoch: 06, loss: -0.49971
# epoch: 07, loss: -0.50569
# epoch: 08, loss: -0.51065
# epoch: 09, loss: -0.51600
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#  99%|█████████▉| 989/1000 [6:57:17<05:01, 27.37s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 989 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0990.pth
# 0990
# Starting Training
# epoch: 00, loss: -0.39559
# epoch: 01, loss: -0.39906
# epoch: 02, loss: -0.39977
# epoch: 03, loss: -0.40067
# epoch: 04, loss: -0.40144
# epoch: 05, loss: -0.40213
# epoch: 06, loss: -0.40337
# epoch: 07, loss: -0.40175
# epoch: 08, loss: -0.40152
# epoch: 09, loss: -0.40091
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#  99%|█████████▉| 990/1000 [6:57:48<04:45, 28.53s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 990 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0991.pth
# 0991
# Starting Training
# epoch: 00, loss: -0.42530
# epoch: 01, loss: -0.43331
# epoch: 02, loss: -0.43566
# epoch: 03, loss: -0.44015
# epoch: 04, loss: -0.44383
# epoch: 05, loss: -0.44634
# epoch: 06, loss: -0.44994
# epoch: 07, loss: -0.45266
# epoch: 08, loss: -0.45460
# epoch: 09, loss: -0.45648
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
#  99%|█████████▉| 991/1000 [6:58:18<04:20, 28.90s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 991 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0992.pth
# 0992
# Starting Training
# epoch: 00, loss: -0.36097
# epoch: 01, loss: -0.36573
# epoch: 02, loss: -0.37250
# epoch: 03, loss: -0.37905
# epoch: 04, loss: -0.38504
# epoch: 05, loss: -0.39028
# epoch: 06, loss: -0.39544
# epoch: 07, loss: -0.40038
# epoch: 08, loss: -0.40401
# epoch: 09, loss: -0.40786
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  99%|█████████▉| 992/1000 [6:58:45<03:47, 28.38s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 992 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0993.pth
# 0993
# Starting Training
# epoch: 00, loss: -0.36049
# epoch: 01, loss: -0.35064
# epoch: 02, loss: -0.35652
# epoch: 03, loss: -0.36668
# epoch: 04, loss: -0.37831
# epoch: 05, loss: -0.38924
# epoch: 06, loss: -0.39923
# epoch: 07, loss: -0.40711
# epoch: 08, loss: -0.41174
# epoch: 09, loss: -0.41453
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  99%|█████████▉| 993/1000 [6:59:11<03:14, 27.84s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 993 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0994.pth
# 0994
# Starting Training
# epoch: 00, loss: -0.58152
# epoch: 01, loss: -0.61527
# epoch: 02, loss: -0.61719
# epoch: 03, loss: -0.61924
# epoch: 04, loss: -0.62120
# epoch: 05, loss: -0.62250
# epoch: 06, loss: -0.62430
# epoch: 07, loss: -0.62555
# epoch: 08, loss: -0.62719
# epoch: 09, loss: -0.62824
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
#  99%|█████████▉| 994/1000 [6:59:37<02:42, 27.09s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])
# 994 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0995.pth
# 0995
# Starting Training
# epoch: 00, loss: -0.36636
# epoch: 01, loss: -0.36440
# epoch: 02, loss: -0.36585
# epoch: 03, loss: -0.36714
# epoch: 04, loss: -0.36946
# epoch: 05, loss: -0.37101
# epoch: 06, loss: -0.37271
# epoch: 07, loss: -0.37387
# epoch: 08, loss: -0.37479
# epoch: 09, loss: -0.37594
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# 100%|█████████▉| 995/1000 [7:00:11<02:25, 29.12s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 995 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0996.pth
# 0996
# Starting Training
# epoch: 00, loss: -0.39917
# epoch: 01, loss: -0.39577
# epoch: 02, loss: -0.38361
# epoch: 03, loss: -0.37886
# epoch: 04, loss: -0.37682
# epoch: 05, loss: -0.37484
# epoch: 06, loss: -0.37321
# epoch: 07, loss: -0.37315
# epoch: 08, loss: -0.37270
# epoch: 09, loss: -0.37293
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# 100%|█████████▉| 996/1000 [7:00:42<01:59, 29.77s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 996 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0997.pth
# 0997
# Starting Training
# epoch: 00, loss: -0.39931
# epoch: 01, loss: -0.40450
# epoch: 02, loss: -0.40214
# epoch: 03, loss: -0.40116
# epoch: 04, loss: -0.40256
# epoch: 05, loss: -0.40733
# epoch: 06, loss: -0.41199
# epoch: 07, loss: -0.41655
# epoch: 08, loss: -0.42218
# epoch: 09, loss: -0.42858
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# 100%|█████████▉| 997/1000 [7:01:10<01:28, 29.42s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 997 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0998.pth
# 0998
# Starting Training
# epoch: 00, loss: -0.49097
# epoch: 01, loss: -0.49050
# epoch: 02, loss: -0.49469
# epoch: 03, loss: -0.49642
# epoch: 04, loss: -0.49789
# epoch: 05, loss: -0.49886
# epoch: 06, loss: -0.49950
# epoch: 07, loss: -0.50021
# epoch: 08, loss: -0.50040
# epoch: 09, loss: -0.50037
# After Unsqueezing, feature size= torch.Size([450, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([450, 384])
# 100%|█████████▉| 998/1000 [7:01:42<01:00, 30.01s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 450])
# 998 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/0999.pth
# 0999
# Starting Training
# epoch: 00, loss: -0.39799
# epoch: 01, loss: -0.41148
# epoch: 02, loss: -0.41631
# epoch: 03, loss: -0.42035
# epoch: 04, loss: -0.42727
# epoch: 05, loss: -0.44037
# epoch: 06, loss: -0.45279
# epoch: 07, loss: -0.46584
# epoch: 08, loss: -0.47848
# epoch: 09, loss: -0.48630
# After Unsqueezing, feature size= torch.Size([375, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([375, 384])
# 100%|█████████▉| 999/1000 [7:02:05<00:27, 27.83s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 375])
# 999 /home/phdcs2/Hard_Disk/Datasets/Deep-Spectral-Segmentation/data/object-segmentation/ECSSD/features/dino_vits16/1000.pth
# 1000
# Starting Training
# epoch: 00, loss: -0.40765
# epoch: 01, loss: -0.40727
# epoch: 02, loss: -0.41097
# epoch: 03, loss: -0.41380
# epoch: 04, loss: -0.41688
# epoch: 05, loss: -0.42036
# epoch: 06, loss: -0.42257
# epoch: 07, loss: -0.42478
# epoch: 08, loss: -0.42681
# epoch: 09, loss: -0.42871
# After Unsqueezing, feature size= torch.Size([400, 1, 384])
# type(projected_feature) <class 'torch.Tensor'>
# projected feature shape= torch.Size([400, 384])
# 100%|██████████| 1000/1000 [7:02:29<00:00, 25.35s/it]
# eigenvalues shape torch.Size([5]) eigenvectors shape torch.Size([5, 400])

# %%
import matplotlib.pyplot as plt
# numpy_array = W_feat.numpy()

# Downsample the tensor by averaging values in small blocks
downsampled_array = np.mean(W_comb.reshape(128, 8, 128, 8), axis=(1, 3))
# downsampled_array = np.mean(W_feat.reshape(64, 16, 64, 16), axis=(1, 3))

# Plot the heatmap of the downsampled tensor
plt.imshow(downsampled_array, cmap='YlGnBu', interpolation='nearest')
plt.colorbar()
plt.title('Conv1D for projector and Predictor')
plt.show()
